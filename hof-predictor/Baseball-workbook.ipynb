# %%
import pandas as pd
import numpy as np

# %%
player = pd.read_csv('Data//people.csv')

# %%
player.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile     2021.0         1.0      22.0  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# ...

# %%
hof = pd.read_csv('Data//HallOfFame.csv')

# %%
hof.head()
# Out:
#     playerID  yearID votedBy  ballots  needed  votes inducted category  \
# 0   cobbty01    1936   BBWAA    226.0   170.0  222.0        Y   Player
# 1   ruthba01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 2  wagneho01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 3  mathech01    1936   BBWAA    226.0   170.0  205.0        Y   Player
# 4  johnswa01    1936   BBWAA    226.0   170.0  189.0        Y   Player
#
#   needed_note
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
player.loc[player ['playerID'] == 'addybo01']
# Out:
#      playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 110  addybo01     1842.0         2.0       NaN          CAN         ON
#
#      birthCity  deathYear  deathMonth  deathDay  ... nameLast      nameGiven  \
# 110  Port Hope     1910.0         4.0       9.0  ...     Addy  Robert Edward
#
#     weight height bats throws       debut   finalGame   retroID   bbrefID
# 110  160.0   68.0    L      L  1871-05-06  1877-10-06  addyb101  addybo01
#
# [1 rows x 24 columns]

# %%
awards = pd.read_csv('Data/AwardsPlayers.csv')

# %%
awards.head()
# Out:
#     playerID                awardID  yearID lgID  tie notes
# 0   bondto01  Pitching Triple Crown    1877   NL  NaN   NaN
# 1  hinespa01           Triple Crown    1878   NL  NaN   NaN
# 2  heckegu01  Pitching Triple Crown    1884   AA  NaN   NaN
# 3  radboch01  Pitching Triple Crown    1884   NL  NaN   NaN
# 4  oneilti01           Triple Crown    1887   AA  NaN   NaN

# %%
m_player = player.loc[player ['debut'] > '1960-01-01']

# %%
m_player.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
# 5   abadfe01     1985.0        12.0      17.0         D.R.  La Romana
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron
# 3      Orange        NaN         NaN       NaN  ...     Aase
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad
# 5   La Romana        NaN         NaN       NaN  ...     Abad
#
#           nameGiven weight height bats throws       debut   finalGame  \
# 0       David Allan  215.0   75.0    R      R  2004-04-06  2015-08-23
# ...

# %%
merge = pd.merge(m_player, hof, on = ['playerID','playerID'])

# %%
merge.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  abbotji01     1967.0         9.0      19.0          USA         MI
# 1   ageeto01     1942.0         8.0       9.0          USA         AL
# 2  aguilri01     1961.0        12.0      31.0          USA         CA
# 3   akerja01     1940.0         7.0      13.0          USA         CA
# 4  alexado01     1950.0         9.0       4.0          USA         AL
#
#      birthCity  deathYear  deathMonth  deathDay  ...   retroID    bbrefID  \
# 0        Flint        NaN         NaN       NaN  ...  abboj001  abbotji01
# 1     Magnolia     2001.0         1.0      22.0  ...  ageet101   ageeto01
# 2  San Gabriel        NaN         NaN       NaN  ...  aguir001  aguilri01
# 3       Tulare        NaN         NaN       NaN  ...  akerj102   akerja01
# 4      Cordova        NaN         NaN       NaN  ...  alexd001  alexado01
#
#   yearID votedBy ballots needed  votes  inducted category needed_note
# ...

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1126 entries, 0 to 1125
# Data columns (total 32 columns):
# playerID        1126 non-null object
# birthYear       1126 non-null float64
# birthMonth      1126 non-null float64
# birthDay        1126 non-null float64
# birthCountry    1126 non-null object
# birthState      1101 non-null object
# birthCity       1126 non-null object
# deathYear       172 non-null float64
# deathMonth      172 non-null float64
# deathDay        172 non-null float64
# deathCountry    172 non-null object
# deathState      172 non-null object
# deathCity       172 non-null object
# nameFirst       1126 non-null object
# nameLast        1126 non-null object
# nameGiven       1126 non-null object
# weight          1126 non-null float64
# height          1126 non-null float64
# bats            1126 non-null object
# throws          1126 non-null object
# debut           1126 non-null object
# finalGame       1126 non-null object
# ...

# %%
batting = pd.read_csv('Data//Batting.csv')
fielding = pd.read_csv('Data//Fielding.csv')

# %%
batting.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0  8.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0  3.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0  1.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0  6.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
# 2  1.0   2  5.0  NaN  NaN NaN NaN   1.0
# 3  1.0   0  2.0  NaN  NaN NaN NaN   0.0
# 4  2.0   2  1.0  NaN  NaN NaN NaN   0.0
#
# [5 rows x 22 columns]

# %%
fielding.head()
# Out:
#     playerID  yearID  stint teamID lgID POS   G    GS  InnOuts  PO   A     E  \
# 0  abercda01    1871      1    TRO  NaN  SS   1   1.0     24.0   1   3   2.0
# 1   addybo01    1871      1    RC1  NaN  2B  22  22.0    606.0  67  72  42.0
# 2   addybo01    1871      1    RC1  NaN  SS   3   3.0     96.0   8  14   7.0
# 3  allisar01    1871      1    CL1  NaN  2B   2   0.0     18.0   1   4   0.0
# 4  allisar01    1871      1    CL1  NaN  OF  29  29.0    729.0  51   3   7.0
#
#    DP  PB  WP  SB  CS  ZR
# 0   0 NaN NaN NaN NaN NaN
# 1   5 NaN NaN NaN NaN NaN
# 2   0 NaN NaN NaN NaN NaN
# 3   0 NaN NaN NaN NaN NaN
# 4   1 NaN NaN NaN NaN NaN

# %%
fielding_1 = fielding['playerID', 'POS', SUM('G'), SUM('GS'), SUM('InnOuts'), SUM('PO'), SUM('A'), SUM('E'), SUM('DP')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4ef05237fa1d> in <module>
# ----> 1 fielding_1 = fielding['playerID', 'POS', SUM('G'), SUM('GS'), SUM('InnOuts'), SUM('PO'), SUM('A'), SUM('E'), SUM('DP')]
#
# NameError: name 'SUM' is not defined

# %%
fielding_1 = fielding.groupby(['playerID','POS'])['G','GS','InnOuts','PO','A','E','DP'].sum()

# %%
fielding_1.head()
# Out:
#                   G      GS  InnOuts    PO    A      E   DP
# playerID  POS
# aardsda01 P     331     0.0   1011.0    11   29    3.0    2
# aaronha01 1B    210   203.0   5274.0  1791  117   20.0  152
#           2B     43    34.0    913.0   102   99    7.0   25
#           3B      7     5.0    153.0     4   12    0.0    0
#           OF   2760  2735.0  72074.0  5539  201  117.0   41

# %%
fielding.loc[fielding ['POS'] != 'P']
# Out:
#          playerID  yearID  stint teamID lgID POS   G    GS  InnOuts   PO    A  \
# 0       abercda01    1871      1    TRO  NaN  SS   1   1.0     24.0    1    3
# 1        addybo01    1871      1    RC1  NaN  2B  22  22.0    606.0   67   72
# 2        addybo01    1871      1    RC1  NaN  SS   3   3.0     96.0    8   14
# 3       allisar01    1871      1    CL1  NaN  2B   2   0.0     18.0    1    4
# 4       allisar01    1871      1    CL1  NaN  OF  29  29.0    729.0   51    3
# 5       allisdo01    1871      1    WS3  NaN   C  27  27.0    681.0   68   15
# 6       ansonca01    1871      1    RC1  NaN  1B   1   0.0     15.0    7    0
# 7       ansonca01    1871      1    RC1  NaN  2B   2   1.0     30.0    3    4
# 8       ansonca01    1871      1    RC1  NaN  3B  20  19.0    555.0   38   52
# 9       ansonca01    1871      1    RC1  NaN   C   5   4.0     93.0   10    0
# 10      ansonca01    1871      1    RC1  NaN  OF   1   1.0      6.0    0    0
# ...

# %%
import findspark
findspark.init()
findspark.find()
import pyspark
findspark.find()
# Out:
# 'C:\\Spark'

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
conf = pyspark.SparkConf().setAppName('appName').setMaster('local')
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession(sc)

# %%
s_players = sc.textFile('Data//people.csv')

# %%
s_players
# Out:
# Data//people.csv MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0

# %%
spark.sql("""""")
